# %% [raw]
# pandas: pandas is a powerful library for data manipulation and analysis in Python. It provides data structures like DataFrame, which is a two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes (rows and columns). Pandas is widely used for data cleaning, exploration, and analysis tasks.
#
# numpy: numpy is a fundamental package for scientific computing in Python. It provides support for arrays, matrices, and mathematical functions to operate on these arrays efficiently. Many other libraries in Python, including pandas, rely on numpy for numerical computations.

# %%
import pandas as pd
import numpy as np

# %% [raw]
# read_csv(): This is a function provided by pandas for reading data from a CSV file into a DataFrame.
#
# r'US Superstore data.csv': This is the path to the CSV file. The r before the string indicates a raw string literal in Python, which is often used for file paths to avoid issues with escape characters.
#
# df: This is the variable name chosen to represent the DataFrame object that will hold the data from the CSV file. You can choose any valid variable name here.

# %%
df=pd.read_csv(r'US Superstore data1.csv')

# %%
df.head()
# Out:
#    SNO.  Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0     0       1  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 1     1       2  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 2     2       3  CA-2016-138688  12-06-2016  16-06-2016    Second Class
# 3     3       4  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 4     4       5  US-2015-108966  11-10-2015  18-10-2015  Standard Class
#
#   Customer ID    Customer Name    Segment        Country  ...  \
# 0    CG-12520      Claire Gute   Consumer  United States  ...
# 1    CG-12520      Claire Gute   Consumer  United States  ...
# 2    DV-13045  Darrin Van Huff  Corporate  United States  ...
# 3    SO-20335   Sean O'Donnell   Consumer  United States  ...
# 4    SO-20335   Sean O'Donnell   Consumer  United States  ...
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# ...

# %% [raw]
# This line of code drops any rows containing NaN values from the DataFrame df and assigns the result back to the variable df, effectively updating df to have those rows removed.

# %%
df=df.dropna()

# %% [raw]
# year=[]: This initializes an empty list named year where we'll store the extracted years.
#
# for i in range(0,len(df)): ...: This is a loop iterating over the indices of the DataFrame df. len(df) returns the number of rows in the DataFrame.
#
# year.append(df['Order Date'][i][6:]): This line of code is doing the actual extraction. It's accessing the 'Order Date' column of the DataFrame at index i, which represents each row in the DataFrame. Then, it's taking a slice from the 6th character to the end of the string. This assumes that the date is in a format where the year starts from the 7th character (index 6). It's assuming that the date format is consistent across all rows.
#
# This code is useful when you want to extract the year from a date column in a DataFrame and store it separately for some analysis or processing.

# %%
year=[]
for i in range(0,len(df)):
  year.append(df['Order Date'][i][6:])

# %%
year
# Out:
# ['2016',
#  '2016',
#  '2016',
#  '2015',
#  '2015',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2017',
#  '2016',
#  '2015',
#  '2015',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2016',
#  '2016',
#  '2017',
#  '2015',
#  '2016',
#  '2016',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2017',
#  '2016',
#  '2016',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2017',
#  '2016',
#  '2017',
#  '2016',
#  '2016',
#  '2014',
#  '2016',
#  '2016',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2014',
#  '2014',
#  '2016',
#  '2016',
#  '2017',
#  '2015',
#  '2015',
#  '2015',
#  '2017',
#  '2017',
#  '2017',
#  '2014',
#  '2016',
#  '2016',
#  '2014',
#  '2014',
#  '2015',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2016',
#  '2016',
# ...

# %% [raw]
# for loop iterates over the elements of the year list. It converts each element to an integer using the int() function and assigns it back to the same position in the year list. This step is necessary because the extracted year values are currently stored as strings, and we want to convert them to integers for further processing.

# %%
for i in range(0,len(df)):
  year[i]=int(year[i])

# %%
year
# Out:
# [2016,
#  2016,
#  2016,
#  2015,
#  2015,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2017,
#  2016,
#  2015,
#  2015,
#  2014,
#  2014,
#  2014,
#  2014,
#  2014,
#  2016,
#  2016,
#  2017,
#  2015,
#  2016,
#  2016,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2017,
#  2016,
#  2016,
#  2015,
#  2015,
#  2015,
#  2015,
#  2017,
#  2016,
#  2017,
#  2016,
#  2016,
#  2014,
#  2016,
#  2016,
#  2015,
#  2015,
#  2015,
#  2015,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2015,
#  2015,
#  2015,
#  2015,
#  2015,
#  2014,
#  2014,
#  2016,
#  2016,
#  2017,
#  2015,
#  2015,
#  2015,
#  2017,
#  2017,
#  2017,
#  2014,
#  2016,
#  2016,
#  2014,
#  2014,
#  2015,
#  2017,
#  2017,
#  2017,
#  2017,
#  2016,
#  2016,
#  2016,
#  2016,
#  2015,
#  2015,
#  2015,
#  2017,
#  2017,
#  2017,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2015,
#  2015,
#  2015,
#  2017,
#  2017,
#  2017,
#  2015,
#  2017,
# ...

# %% [raw]
# df['Order_year']=year: Finally, it creates a new column in the DataFrame df called 'Order_year' and assigns the values from the year list to this column. Each value in the 'Order_year' column corresponds to the year extracted from the 'Order Date' column of the DataFrame.

# %%
df['Order_year']=year

# %%
#Within the loop, it extracts the day and month components from the 'Order Date' and 'Ship Date' columns of the DataFrame
#This code uses slicing to extract the day and month components from the date strings.
#For example, df['Order Date'][i][:2] extracts the first two characters from the 'Order Date' string, which represent the day.
diffd=[]
diffm=[]
for i in range(0,len(df)):
    d1=int(df['Order Date'][i][:2])
    m1=int(df['Order Date'][i][3:5])
    d2=int(df['Ship Date'][i][:2])
    m2=int(df['Ship Date'][i][3:5])

    #It calculates the differences in days and months between the 'Order Date' and 'Ship Date':
    dres=d2-d1
    mres=m2-m1
    #After the loop completes, the diffd and diffm lists will contain the differences in days and months for each row in the DataFrame.
    diffd.append(dres)
    diffm.append(mres)

# %%
#These lines create two new columns in the DataFrame df named 'difference days' and 'difference months' respectively, 
#and assign the values from the diffd and diffm lists to these columns.

df['difference days']=diffd
df['difference months']=diffm

# %%
df
# Out:
#       SNO.  Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        0       1  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 1        1       2  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 2        2       3  CA-2016-138688  12-06-2016  16-06-2016    Second Class
# 3        3       4  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 4        4       5  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# ...    ...     ...             ...         ...         ...             ...
# 9989  9989    9990  CA-2014-110422  21-01-2014  23-01-2014    Second Class
# 9990  9990    9991  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9991  9991    9992  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9992  9992    9993  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9993  9993    9994  CA-2017-119914  04-05-2017  09-05-2017    Second Class
#
# ...

# %%
df['difference months'].value_counts()
# Out:
# difference months
#  0     8835
#  1     1007
# -11     152
# Name: count, dtype: int64

# %%
df['difference days'].value_counts()
# Out:
# difference days
#  4     2458
#  5     1892
#  2     1232
#  6      976
#  3      916
#  0      519
#  7      475
#  1      367
# -26     284
# -27     241
# -25     237
# -24     188
# -29      73
# -28      65
# -23      61
# -22       6
# -21       2
# -30       2
# Name: count, dtype: int64

# %%
my_dict={-26:4, -27:3,-28:2,-29:1,-23:7,-22:8,-21:9,-30:1,-25:5,-24:6}

# %%
for i in df['difference days']:
  if(i<0):
    i=my_dict[i]

# %%
df
# Out:
#       SNO.  Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        0       1  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 1        1       2  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 2        2       3  CA-2016-138688  12-06-2016  16-06-2016    Second Class
# 3        3       4  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 4        4       5  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# ...    ...     ...             ...         ...         ...             ...
# 9989  9989    9990  CA-2014-110422  21-01-2014  23-01-2014    Second Class
# 9990  9990    9991  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9991  9991    9992  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9992  9992    9993  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9993  9993    9994  CA-2017-119914  04-05-2017  09-05-2017    Second Class
#
# ...

# %%
df=df.drop('difference months',axis=1)

# %%
for i in range(0,len( df['difference days'])):
  if(df['difference days'][i]<0):
    df['difference days'][i]=my_dict[df['difference days'][i]]
# Out:
# C:\Users\aaryan\AppData\Local\Temp\ipykernel_9988\1861820271.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['difference days'][i]=my_dict[df['difference days'][i]]
# ...

# %%
df
# Out:
#       SNO.  Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        0       1  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 1        1       2  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 2        2       3  CA-2016-138688  12-06-2016  16-06-2016    Second Class
# 3        3       4  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 4        4       5  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# ...    ...     ...             ...         ...         ...             ...
# 9989  9989    9990  CA-2014-110422  21-01-2014  23-01-2014    Second Class
# 9990  9990    9991  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9991  9991    9992  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9992  9992    9993  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9993  9993    9994  CA-2017-119914  04-05-2017  09-05-2017    Second Class
#
# ...

# %%
import os

# %%
profit_percentage=[]
for i in range(0,len(df)):
  profitp=df['Profit'][i]/df['Sales'][i]
  profit_percentage.append(profitp)

# %%
for i in range(0,len(profit_percentage)):
  profit_percentage[i]=profit_percentage[i]*100

# %%
profit_percentage
# Out:
# [16.000000000000004,
#  30.0,
#  47.0,
#  -40.0,
#  11.25,
#  28.999999999999996,
#  27.0,
#  10.0,
#  31.249999999999993,
#  30.0,
#  5.0,
#  7.500000000000001,
#  35.0,
#  32.49999999999999,
#  -180.0,
#  -150.0,
#  2.0,
#  18.0,
#  28.999999999999996,
#  7.5,
#  32.5,
#  25.999999999999996,
#  25.999999999999996,
#  -1.4285714285714286,
#  23.0,
#  36.25000000000001,
#  13.0,
#  -54.0,
#  -73.33333333333334,
#  12.5,
#  33.75,
#  11.249999999999998,
#  -83.33333333333334,
#  22.499999999999996,
#  33.75,
#  11.249999999999998,
#  -77.5,
#  31.25,
#  -8.823529411764707,
#  -7.142857142857144,
#  11.25,
#  11.249999999999998,
#  5.0,
#  10.0,
#  43.00000000000001,
#  47.0,
#  4.0,
#  11.0,
#  27.999999999999996,
#  47.0,
#  47.0,
#  48.0,
#  19.0,
#  41.0,
#  28.999999999999996,
#  25.0,
#  48.0,
#  2.222222222222222,
#  48.0,
#  11.0,
#  33.75,
#  50.0,
#  44.0,
#  36.25,
#  47.0,
#  27.999999999999996,
#  -7.142857142857142,
#  10.000000000000002,
#  37.5,
#  47.00000000000001,
# ...

# %%
loss_percentage=[]
for i in range(0,len(profit_percentage)):
  loss_percentage.append(1-profit_percentage[i])

# %%
loss_percentage
# Out:
# [-15.000000000000004,
#  -29.0,
#  -46.0,
#  41.0,
#  -10.25,
#  -27.999999999999996,
#  -26.0,
#  -9.0,
#  -30.249999999999993,
#  -29.0,
#  -4.0,
#  -6.500000000000001,
#  -34.0,
#  -31.499999999999993,
#  181.0,
#  151.0,
#  -1.0,
#  -17.0,
#  -27.999999999999996,
#  -6.5,
#  -31.5,
#  -24.999999999999996,
#  -24.999999999999996,
#  2.428571428571429,
#  -22.0,
#  -35.25000000000001,
#  -12.0,
#  55.0,
#  74.33333333333334,
#  -11.5,
#  -32.75,
#  -10.249999999999998,
#  84.33333333333334,
#  -21.499999999999996,
#  -32.75,
#  -10.249999999999998,
#  78.5,
#  -30.25,
#  9.823529411764707,
#  8.142857142857144,
#  -10.25,
#  -10.249999999999998,
#  -4.0,
#  -9.0,
#  -42.00000000000001,
#  -46.0,
#  -3.0,
#  -10.0,
#  -26.999999999999996,
#  -46.0,
#  -46.0,
#  -47.0,
#  -18.0,
#  -40.0,
#  -27.999999999999996,
#  -24.0,
#  -47.0,
#  -1.2222222222222219,
#  -47.0,
#  -10.0,
#  -32.75,
#  -49.0,
#  -43.0,
#  -35.25,
#  -46.0,
#  -26.999999999999996,
#  8.142857142857142,
# ...

# %%
df['profit_percentage']=profit_percentage
df['loss_percentage']=loss_percentage

# %%
df
# Out:
#       SNO.  Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        0       1  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 1        1       2  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 2        2       3  CA-2016-138688  12-06-2016  16-06-2016    Second Class
# 3        3       4  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 4        4       5  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# ...    ...     ...             ...         ...         ...             ...
# 9989  9989    9990  CA-2014-110422  21-01-2014  23-01-2014    Second Class
# 9990  9990    9991  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9991  9991    9992  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9992  9992    9993  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9993  9993    9994  CA-2017-119914  04-05-2017  09-05-2017    Second Class
#
# ...

# %%
df['Days_to_deliever']=df['difference days']
df=df.drop('difference days',axis=1)

# %%
df
# Out:
#       SNO.  Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        0       1  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 1        1       2  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 2        2       3  CA-2016-138688  12-06-2016  16-06-2016    Second Class
# 3        3       4  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 4        4       5  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# ...    ...     ...             ...         ...         ...             ...
# 9989  9989    9990  CA-2014-110422  21-01-2014  23-01-2014    Second Class
# 9990  9990    9991  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9991  9991    9992  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9992  9992    9993  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9993  9993    9994  CA-2017-119914  04-05-2017  09-05-2017    Second Class
#
# ...

# %%
months=[]
for i in range(0,len(df)):
  m=df['Order Date'][i][3:5]
  months.append(m)

# %%
for i in range(0,len(df)):
 months[i]=int(months[i])

# %%
df['Order_month']=months

# %%
df
# Out:
#       SNO.  Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        0       1  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 1        1       2  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 2        2       3  CA-2016-138688  12-06-2016  16-06-2016    Second Class
# 3        3       4  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 4        4       5  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# ...    ...     ...             ...         ...         ...             ...
# 9989  9989    9990  CA-2014-110422  21-01-2014  23-01-2014    Second Class
# 9990  9990    9991  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9991  9991    9992  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9992  9992    9993  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9993  9993    9994  CA-2017-119914  04-05-2017  09-05-2017    Second Class
#
# ...

# %%
quarter=[]
for i in range(0,len(df)):
  if(df['Order_month'][i]<=3):
    x='Q1'
    quarter.append(x)
  elif(df['Order_month'][i]>3 and df['Order_month'][i]<=6):
    x='Q2'
    quarter.append(x)
  elif(df['Order_month'][i]>6 and df['Order_month'][i]<=9):
    x='Q3'
    quarter.append(x)
  elif(df['Order_month'][i]>9):
    x='Q4'
    quarter.append(x)

# %%
quarter
# Out:
# ['Q4',
#  'Q4',
#  'Q2',
#  'Q4',
#  'Q4',
#  'Q2',
#  'Q2',
#  'Q2',
#  'Q2',
#  'Q2',
#  'Q2',
#  'Q2',
#  'Q2',
#  'Q4',
#  'Q4',
#  'Q4',
#  'Q4',
#  'Q2',
#  'Q3',
#  'Q3',
#  'Q3',
#  'Q4',
#  'Q4',
#  'Q3',
#  'Q3',
#  'Q1',
#  'Q1',
#  'Q3',
#  'Q3',
#  'Q3',
#  'Q3',
#  'Q3',
#  'Q3',
#  'Q3',
#  'Q4',
#  'Q4',
#  'Q4',
#  'Q4',
#  'Q4',
#  'Q4',
#  'Q4',
#  'Q3',
#  'Q3',
#  'Q3',
#  'Q1',
#  'Q1',
#  'Q4',
#  'Q2',
#  'Q2',
#  'Q2',
#  'Q2',
#  'Q2',
#  'Q2',
#  'Q4',
#  'Q4',
#  'Q2',
#  'Q2',
#  'Q2',
#  'Q2',
#  'Q2',
#  'Q2',
#  'Q2',
#  'Q4',
#  'Q4',
#  'Q4',
#  'Q4',
#  'Q2',
#  'Q4',
#  'Q4',
#  'Q2',
#  'Q3',
#  'Q3',
#  'Q2',
#  'Q2',
#  'Q2',
#  'Q4',
#  'Q4',
#  'Q4',
#  'Q4',
#  'Q2',
#  'Q2',
#  'Q4',
#  'Q4',
#  'Q3',
#  'Q4',
#  'Q2',
#  'Q4',
#  'Q4',
#  'Q2',
#  'Q3',
#  'Q3',
#  'Q3',
#  'Q1',
#  'Q1',
#  'Q1',
#  'Q4',
#  'Q4',
#  'Q2',
#  'Q3',
#  'Q3',
#  'Q3',
#  'Q3',
#  'Q4',
#  'Q4',
#  'Q4',
#  'Q4',
#  'Q4',
#  'Q4',
#  'Q4',
#  'Q4',
#  'Q4',
# ...

# %%
df['Quarter']=quarter

# %%
df
# Out:
#       SNO.  Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        0       1  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 1        1       2  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 2        2       3  CA-2016-138688  12-06-2016  16-06-2016    Second Class
# 3        3       4  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 4        4       5  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# ...    ...     ...             ...         ...         ...             ...
# 9989  9989    9990  CA-2014-110422  21-01-2014  23-01-2014    Second Class
# 9990  9990    9991  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9991  9991    9992  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9992  9992    9993  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9993  9993    9994  CA-2017-119914  04-05-2017  09-05-2017    Second Class
#
# ...

# %%
#This specifies the axis along which the operation will be performed.
#When axis=1, it means the operation will be performed along columns. So, the code will drop the column named 'profit_percentage' from the DataFrame df.

df=df.drop('profit_percentage',axis=1)

# %%
df
# Out:
#       SNO.  Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        0       1  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 1        1       2  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 2        2       3  CA-2016-138688  12-06-2016  16-06-2016    Second Class
# 3        3       4  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 4        4       5  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# ...    ...     ...             ...         ...         ...             ...
# 9989  9989    9990  CA-2014-110422  21-01-2014  23-01-2014    Second Class
# 9990  9990    9991  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9991  9991    9992  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9992  9992    9993  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9993  9993    9994  CA-2017-119914  04-05-2017  09-05-2017    Second Class
#
# ...

# %%
mdict={1:'January',2:'Feburary',3:'March',4:'April',5:'May',6:'June',7:"July",8:"August",9:"September",10:"October",11:'November',12:"December"}

# %%
for i in range(0,len( df['Order_month'])):
  
    df['Order_month'][i]=mdict[df['Order_month'][i]]
# Out:
# C:\Users\aaryan\AppData\Local\Temp\ipykernel_9988\2587907359.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Order_month'][i]=mdict[df['Order_month'][i]]
# ...

# %%
df
# Out:
#       SNO.  Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        0       1  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 1        1       2  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 2        2       3  CA-2016-138688  12-06-2016  16-06-2016    Second Class
# 3        3       4  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 4        4       5  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# ...    ...     ...             ...         ...         ...             ...
# 9989  9989    9990  CA-2014-110422  21-01-2014  23-01-2014    Second Class
# 9990  9990    9991  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9991  9991    9992  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9992  9992    9993  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9993  9993    9994  CA-2017-119914  04-05-2017  09-05-2017    Second Class
#
# ...

# %%
df['Ship Date'][1][6:]
# Out:
# '2016'

# %%
ship_year=[]
for i in range(0,len(df)):
  x=int(df['Ship Date'][i][6:])
  ship_year.append(x)

# %%
df['Shipping_year']=ship_year

# %%
df['shipping_quarter']=df['Quarter']

# %%
df
# Out:
#       SNO.  Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        0       1  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 1        1       2  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 2        2       3  CA-2016-138688  12-06-2016  16-06-2016    Second Class
# 3        3       4  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 4        4       5  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# ...    ...     ...             ...         ...         ...             ...
# 9989  9989    9990  CA-2014-110422  21-01-2014  23-01-2014    Second Class
# 9990  9990    9991  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9991  9991    9992  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9992  9992    9993  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9993  9993    9994  CA-2017-119914  04-05-2017  09-05-2017    Second Class
#
# ...

# %%
# it will take the contents of the DataFrame df and write them to a file named 'final_data.csv' in CSV format 
# effectively creating a CSV file containing the data from the DataFrame.

df.to_csv('final_data.csv')
